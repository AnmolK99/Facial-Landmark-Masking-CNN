# %%
import pandas as pd
import numpy as np
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from keras import optimizers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
raw = pd.read_csv('datasets/training.zip', compression='zip', header=0, sep=',', quotechar='"')
test_data = pd.read_csv('datasets/test.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
raw.head()
raw.describe()
# Out:
#        left_eye_center_x  ...  mouth_center_bottom_lip_y
# count        7039.000000  ...                7016.000000
# mean           66.359021  ...                  78.970146
# std             3.448233  ...                   5.407844
# min            22.763345  ...                  25.850503
# 25%            65.082895  ...                  75.549715
# 50%            66.497566  ...                  78.696326
# 75%            68.024752  ...                  82.233993
# max            94.689280  ...                  95.808983
#
# [8 rows x 30 columns]

# %%
# Null value filled with previous data to avoid loss of data
raw.fillna(method = "ffill",inplace=True)
raw.isnull().any().value_counts()
raw.describe()
# Out:
#        left_eye_center_x  ...  mouth_center_bottom_lip_y
# count        7049.000000  ...                7049.000000
# mean           66.358588  ...                  78.979256
# std             3.447098  ...                   5.406621
# min            22.763345  ...                  25.850503
# 25%            65.082643  ...                  75.553726
# 50%            66.493907  ...                  78.704640
# 75%            68.024628  ...                  82.236528
# max            94.689280  ...                  95.808983
#
# [8 rows x 30 columns]

# %%
# Creation of Images from raw data for Model training and testing to detect the facial Landmarks

images = []
for i in range(0,7049):
    img = raw["Image"][i].split(" ")
    img = ['0' if x ==" " else x for x in img]
    images.append(img)

images = np.array(images,dtype='float')
images.shape
# Out:
# (7049, 9216)

# %%
training = raw.drop(["Image"],axis=1)
training.head()
# Out:
#    left_eye_center_x  ...  mouth_center_bottom_lip_y
# 0          66.033564  ...                  84.485774
# 1          64.332936  ...                  85.480170
# 2          65.057053  ...                  78.659368
# 3          65.225739  ...                  78.268383
# 4          66.725301  ...                  86.871166
#
# [5 rows x 30 columns]

# %%
y_train = []
for i in range(0,7049):
    y = training.iloc[i,:]
    y_train.append(y)
ytrain = np.array(y_train,dtype = 'float')

# %%
# Shaping the Images uniformly for our model to get trained on.
xtrain = images.reshape(-1,96,96)
plt.imshow(xtrain[91].reshape(96,96),cmap='gray')
plt.show()

# Converting Image color range(0,255) into range (0,1)
for row in images:
    row/=255

# %%
# lets have a look at our images
plt.imshow(images[0].reshape(96,96),cmap='gray')
plt.show()

# %%
training = raw.drop(["Image"],axis=1)
training.head()
# Out:
#    left_eye_center_x  ...  mouth_center_bottom_lip_y
# 0          66.033564  ...                  84.485774
# 1          64.332936  ...                  85.480170
# 2          65.057053  ...                  78.659368
# 3          65.225739  ...                  78.268383
# 4          66.725301  ...                  86.871166
#
# [5 rows x 30 columns]

# %%
# Model 2
# Final Modal

model = Sequential()
model.add(Convolution2D(32, (3, 3) ,activation='relu', input_shape=(96, 96, 1)))
model.add(Convolution2D(32, (3, 3) , padding="same",activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(64, (3, 3) , padding="same",activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(128, (3, 3) , padding="same",activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dense(30, activation='relu'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 94, 94, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 94, 94, 32)        9248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 94, 94, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 47, 47, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 47, 47, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 11, 11, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 15488)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1982592
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                3870
# =================================================================
# Total params: 2,105,790
# Trainable params: 2,105,342
# Non-trainable params: 448
# _________________________________________________________________

# %%
model.compile(loss='mse',
              optimizer='adam',
              metrics=['mae',"accuracy"])

images=images.reshape(-1,96,96,1)
images.shape
# Out:
# (7049, 96, 96, 1)

# %%
history = model.fit(images, ytrain,epochs = 100,batch_size = 255,validation_split = 0.2)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 4s 159ms/step - loss: 51.6815 - mae: 3.1499 - accuracy: 0.7306 - val_loss: 160.9874 - val_mae: 11.0884 - val_accuracy: 0.7177
# Epoch 2/100
# 23/23 [==============================] - 4s 158ms/step - loss: 52.7855 - mae: 3.2562 - accuracy: 0.7173 - val_loss: 120.8209 - val_mae: 9.0976 - val_accuracy: 0.7050
# Epoch 3/100
# 23/23 [==============================] - 4s 159ms/step - loss: 52.2383 - mae: 3.2249 - accuracy: 0.7297 - val_loss: 172.0056 - val_mae: 11.5730 - val_accuracy: 0.7234
# Epoch 4/100
# 23/23 [==============================] - 4s 160ms/step - loss: 51.8486 - mae: 3.1713 - accuracy: 0.7370 - val_loss: 179.8980 - val_mae: 11.8619 - val_accuracy: 0.7121
# Epoch 5/100
# 23/23 [==============================] - 4s 161ms/step - loss: 51.5838 - mae: 3.1332 - accuracy: 0.7292 - val_loss: 178.7822 - val_mae: 11.8448 - val_accuracy: 0.7128
# Epoch 6/100
# 23/23 [==============================] - 4s 162ms/step - loss: 52.0402 - mae: 3.1809 - accuracy: 0.7342 - val_loss: 146.4825 - val_mae: 10.5228 - val_accuracy: 0.7035
# Epoch 7/100
# 23/23 [==============================] - 4s 163ms/step - loss: 52.3236 - mae: 3.2061 - accuracy: 0.7285 - val_loss: 217.4261 - val_mae: 13.3038 - val_accuracy: 0.7113
# Epoch 8/100
# 23/23 [==============================] - 4s 164ms/step - loss: 51.6977 - mae: 3.1523 - accuracy: 0.7289 - val_loss: 135.1936 - val_mae: 9.9527 - val_accuracy: 0.7177
# Epoch 9/100
# 23/23 [==============================] - 4s 165ms/step - loss: 51.8396 - mae: 3.1730 - accuracy: 0.7349 - val_loss: 116.2931 - val_mae: 8.9908 - val_accuracy: 0.7085
# Epoch 10/100
# 23/23 [==============================] - 4s 167ms/step - loss: 51.6475 - mae: 3.1090 - accuracy: 0.7349 - val_loss: 182.1999 - val_mae: 11.9872 - val_accuracy: 0.7106
# Epoch 11/100
# 23/23 [==============================] - 4s 165ms/step - loss: 51.9118 - mae: 3.1381 - accuracy: 0.7461 - val_loss: 153.2450 - val_mae: 10.7421 - val_accuracy: 0.7199
# Epoch 12/100
# 23/23 [==============================] - 4s 162ms/step - loss: 51.4327 - mae: 3.1172 - accuracy: 0.7359 - val_loss: 174.8206 - val_mae: 11.6644 - val_accuracy: 0.7184
# Epoch 13/100
# 23/23 [==============================] - 4s 162ms/step - loss: 51.2916 - mae: 3.1282 - accuracy: 0.7384 - val_loss: 166.3054 - val_mae: 11.3503 - val_accuracy: 0.7227
# Epoch 14/100
# Epoch 93/100
# 23/23 [==============================] - 4s 160ms/step - loss: 5.9118 - mae: 1.6270 - accuracy: 0.7771 - val_loss: 99.8614 - val_mae: 9.1259 - val_accuracy: 0.7376
# Epoch 94/100
# 23/23 [==============================] - 4s 160ms/step - loss: 5.0981 - mae: 1.5109 - accuracy: 0.7939 - val_loss: 79.6129 - val_mae: 8.1268 - val_accuracy: 0.7716
# Epoch 95/100
# 23/23 [==============================] - 4s 160ms/step - loss: 4.9629 - mae: 1.4840 - accuracy: 0.7897 - val_loss: 90.7208 - val_mae: 8.6966 - val_accuracy: 0.7660
# Epoch 96/100
# 23/23 [==============================] - 4s 161ms/step - loss: 5.2683 - mae: 1.5461 - accuracy: 0.7888 - val_loss: 81.7564 - val_mae: 8.3077 - val_accuracy: 0.7610
# Epoch 97/100
# 23/23 [==============================] - 4s 161ms/step - loss: 4.7497 - mae: 1.4861 - accuracy: 0.7874 - val_loss: 98.6294 - val_mae: 9.0606 - val_accuracy: 0.7645
# Epoch 98/100
# 23/23 [==============================] - 4s 161ms/step - loss: 4.6879 - mae: 1.4677 - accuracy: 0.8044 - val_loss: 127.9626 - val_mae: 10.4141 - val_accuracy: 0.7496
# Epoch 99/100
# 23/23 [==============================] - 4s 160ms/step - loss: 5.0387 - mae: 1.5027 - accuracy: 0.7987 - val_loss: 102.9378 - val_mae: 9.2861 - val_accuracy: 0.7511
# Epoch 100/100
# 23/23 [==============================] - 4s 161ms/step - loss: 4.9461 - mae: 1.5179 - accuracy: 0.7941 - val_loss: 89.9588 - val_mae: 8.7012 - val_accuracy: 0.7709

# %%
#model.save("facial_keypoints_model_100Epocs.h5")
model = tf.keras.models.load_model('facial_keypoints_model_100Epocs.h5')

# %%
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')  
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %%
# for key in history.history.keys():
#     print(key)

# %%
test_data.head()
testy = test_data
testdata = testy["Image"]
testimages = []
for i in range(0,1783):
    img = raw["Image"][i].split(" ")
    img = ['0' if x ==" " else x for x in img]
    testimages.append(img)
testimages = np.array(testimages,dtype="float")
testimages/=255
testimages = testimages.reshape(-1,96,96,1)
testimages.shape
# Out:
# (1783, 96, 96, 1)

# %%
result = model.predict(testimages,verbose=1)
# Out:
# 56/56 [==============================] - 14s 243ms/step

# %%
# plt.imshow(testimages[178].reshape(96,96),cmap='gray')
# plt.show()

# %%
result.shape
result[0]
# Out:
# (1783, 30)

# %%
# imagenum=1746
# image=(testimages[imagenum].reshape(96,96)).copy()
# plt.imshow(image)
# plt.plot(640, 570, "og", markersize=10)  # og:shorthand for green circle
# plt.scatter(pts[:, 0], pts[:, 1], marker="x", color="red", s=200)
# plt.show()

# %%
imagenum=1756
image=(testimages[imagenum].reshape(96,96)).copy()
plt.imshow(image.reshape(96,96),cmap='gray')
plt.show()
for i in range(0,15):
  image=cv2.circle(image, (result[imagenum][i*2],result[imagenum][i*2+1]), 1,255,-1)
plt.imshow(image.reshape(96,96),cmap='gray')
plt.show()

# %%
image = cv2.circle(image, center_coordinates, radius, color, thickness)
